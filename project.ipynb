# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv("/content/drive/MyDrive/onlinepaymentfraud (1).csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
data.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 50%      1.327057e+05    2.146614e+05  0.000000e+00    0.000000e+00
# 75%      9.430367e+05    1.111909e+06  0.000000e+00    0.000000e+00
# max      3.560159e+08    3.561793e+08  1.000000e+00    1.000000e+00

# %%
data.shape
# Out:
# (6362620, 11)

# %%
print(data.isnull().sum())
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
data.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
data.tail()
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 6362615             0.0   C776919290            0.00       339682.13        1
# 6362616             0.0  C1881841831            0.00            0.00        1
# 6362617             0.0  C1365125890        68488.84      6379898.11        1
# 6362618             0.0  C2080388513            0.00            0.00        1
# 6362619             0.0   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0

# %%
sns.countplot(x='type', data=data)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.countplot(x='isFraud', data=data)
# Out:
# <Axes: xlabel='isFraud', ylabel='count'>

# %%
data['isFraud'].value_counts()
# Out:
# 0    6354407
# 1       8213
# Name: isFraud, dtype: int64

# %%
# Downsampling to balance the dataset
is_notfraud = data[data.isFraud == 0]
is_fraud= data[data.isFraud == 1]
is_notfraud = is_notfraud.sample(n=len(is_fraud),
						random_state=42)

balanced_data = is_notfraud.append(is_fraud)\
    .reset_index(drop=True)
# Out:
# <ipython-input-14-6d7550f36220>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   balanced_data = is_notfraud.append(is_fraud)\

# %%
sns.countplot(data = balanced_data, x='isFraud')
# Out:
# <Axes: xlabel='isFraud', ylabel='count'>

# %%
balanced_data['isFraud'].value_counts()
# Out:
# 0    8213
# 1    8213
# Name: isFraud, dtype: int64

# %%
balanced_data.head()
# Out:
#    step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   162  CASH_OUT  183806.32   C691771226       19391.00            0.00
# 1   137   PAYMENT     521.37   C203378011           0.00            0.00
# 2   179   PAYMENT    3478.18  C1698571270       19853.00        16374.82
# 3   355   PAYMENT    1716.05   C913764937        5769.17         4053.13
# 4   354   CASH_IN  253129.93  C2017736577     1328499.49      1581629.42
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  C1416312719       382572.19       566378.51        0               0
# 1    M42773300            0.00            0.00        0               0
# 2   M643984524            0.00            0.00        0               0
# 3  M1387429131            0.00            0.00        0               0
# 4   C407484102      2713220.48      2460090.55        0               0

# %%
balanced_data.tail()
# Out:
#        step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 16421   743  CASH_OUT   339682.13   C786484425      339682.13             0.0
# 16422   743  TRANSFER  6311409.28  C1529008245     6311409.28             0.0
# 16423   743  CASH_OUT  6311409.28  C1162922333     6311409.28             0.0
# 16424   743  TRANSFER   850002.52  C1685995037      850002.52             0.0
# 16425   743  CASH_OUT   850002.52  C1280323807      850002.52             0.0
#
#           nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 16421   C776919290            0.00       339682.13        1               0
# 16422  C1881841831            0.00            0.00        1               0
# 16423  C1365125890        68488.84      6379898.11        1               0
# 16424  C2080388513            0.00            0.00        1               0
# 16425   C873221189      6510099.11      7360101.63        1               0

# %%
sns.countplot(x='type', data=balanced_data)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.barplot(x='type', y='amount', data=balanced_data)
# Out:
# <Axes: xlabel='type', ylabel='amount'>

# %%
plt.figure(figsize=(15, 6))
sns.distplot(balanced_data['step'], bins=50)
# Out:
# <ipython-input-21-7d7dcdbdda68>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(balanced_data['step'], bins=50)
# <Axes: xlabel='step', ylabel='Density'>

# %%
#converting categorical value to the numerical
balanced_data["type"] = balanced_data["type"].map({"CASH_OUT": 1, "PAYMENT": 2,
                                 "CASH_IN": 3, "TRANSFER": 4,
                                 "DEBIT": 5})
print(balanced_data.head())
# Out:
#    step  type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   162     1  183806.32   C691771226       19391.00            0.00
# 1   137     2     521.37   C203378011           0.00            0.00
# 2   179     2    3478.18  C1698571270       19853.00        16374.82
# 3   355     2    1716.05   C913764937        5769.17         4053.13
# 4   354     3  253129.93  C2017736577     1328499.49      1581629.42
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  C1416312719       382572.19       566378.51        0               0
# 1    M42773300            0.00            0.00        0               0
# 2   M643984524            0.00            0.00        0               0
# 3  M1387429131            0.00            0.00        0               0
# 4   C407484102      2713220.48      2460090.55        0               0

# %%
balanced_data.type.value_counts()
# Out:
# 1    7066
# 4    4750
# 2    2735
# 3    1825
# 5      50
# Name: type, dtype: int64

# %%
balanced_data.type.unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
CrosstabResult=pd.crosstab(index=balanced_data.type,columns=balanced_data.isFraud)
CrosstabResult
# Out:
# isFraud     0     1
# type
# 1        2950  4116
# 2        2735     0
# 3        1825     0
# 4         653  4097
# 5          50     0

# %%
total_fraud= balanced_data[balance.isFraud ==1]
total_fraud = total_fraud.shape[0]
total_fraud
# Out:
# 8213
